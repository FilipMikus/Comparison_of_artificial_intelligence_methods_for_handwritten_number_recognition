# %% [markdown]
# # YOLO v5 (ARDIS)

# %% [markdown]
# ---
# ## Importovanie modulov:

# %%
import torch
from IPython.display import Image, display, clear_output
import os 
import random
import shutil
import glob
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ---
# ## Trenovanie - spustenie trénovania modelu:

# %%
# !python yolo_v5/train.py --img 128 --batch 8 --epochs 3000 --data datasets/ardis/ardis_yolo_copy/ardis_yolo.yaml --weights yolov5s.pt

# %% [markdown]
# ---
# ## Inferencia - vytvorenie modelu:

# %%
# !python yolo_v5/detect.py --source datasets/ardis/ardis_yolo_copy/test/digits_all_8x8 --weights yolo_v5/runs/train/exp/weights/best.pt --conf 0.5 --name yolo_road_det --hide-conf --hide-label
# Out:
# detect: weights=['yolo_v5/runs/train/exp/weights/best.pt'], source=datasets/ardis/ardis_yolo_copy/test/digits_all_8x8, data=yolo_v5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolo_v5/runs/detect, name=yolo_road_det, exist_ok=False, line_thickness=3, hide_labels=True, hide_conf=True, half=False, dnn=False
# YOLOv5 🚀 2022-4-27 torch 1.11.0+cu102 CUDA:0 (NVIDIA GeForce GTX 1080 Ti, 11175MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7037095 parameters, 0 gradients, 15.9 GFLOPs
# image 1/10 /home/filipmikus/bp/yolo/datasets/ardis/ardis_yolo_copy/test/digits_all_8x8/grid0.png: 640x640 64 0s, Done. (0.006s)
# image 2/10 /home/filipmikus/bp/yolo/datasets/ardis/ardis_yolo_copy/test/digits_all_8x8/grid1.png: 640x640 64 1s, 1 4, Done. (0.006s)
# ...

# %%
model = torch.hub.load('yolo_v5','custom', path='yolo_v5/runs/train/exp/weights/best.pt', force_reload=True, source='local')

# %% [markdown]
# ---
# ## Inferencia - detekcia:

# %% [markdown]
# ### Detekcia na ARDIS 2x2 vzorkách:

# %%
img = "yolo_v5/runs/detect/yolo_road_det/grid6.png"
display(Image(img))

# %% [markdown]
# ### Detekcia na ARDIS 4x4 vzorkách:

# %%
img = "yolo_v5/runs/detect/yolo_road_det2/grid5.png"
display(Image(img))

# %% [markdown]
# ### Detekcia na ARDIS 8x8 vzorkách:

# %%
img = "yolo_v5/runs/detect/yolo_road_det3/grid0.png"
display(Image(img))

# %% [markdown]
# ### Detekcia na ARDIS 10x10 vzorkách:

# %%
img = "yolo_v5/runs/detect/yolo_road_det4/grid0.png"
display(Image(img))

# %% [markdown]
# ### Detekcia na ARDIS 12x12 vzorkách:

# %%
img = "yolo_v5/runs/detect/yolo_road_det5/grid0.png"
display(Image(img))

# %% [markdown]
# ### Detekcia na ARDIS 14x14 vzorkách:

# %%
img = "yolo_v5/runs/detect/yolo_road_det6/grid0.png"
display(Image(img))

# %% [markdown]
# ### Detekcia na ARDIS 16x16 vzorkách:

# %%
img = "yolo_v5/runs/detect/yolo_road_det7/grid0.png"
display(Image(img))

# %% [markdown]
# ### Detekcia na ARDIS 18x18 vzorkách:

# %%
img = "yolo_v5/runs/detect/yolo_road_det8/grid0.png"
display(Image(img))

# %% [markdown]
# ---
# ## Inferencia - klasifikácia:

# %% [markdown]
# ### Klasifikácia čislice 0 na ARDIS 8x8 vzorke:

# %%
display(Image("yolo_v5/runs/detect/yolo_road_det9/gr
na ARDIS 8x8 vzorke:

# %%
display(Image("yolo_v5/runs/detect/yolo_road_det9/grid7.png"))
results = model("datasets/ardis/ardis_yolo_copy/test/digits_all_8x8/grid7.png")
pd_results = results.pandas().xyxy[0]
print(pd_results.to_string())
# Out:
#           xmin        ymin        xmax        ymax  confidence  class name
# 0    55.451378  167.886642   83.673874  196.623581    0.951969      7    7
# 1   112.358200  167.382172  139.658112  196.480515    0.951719      7    7
# 2   167.560608   55.921684  196.080231   83.519585    0.951158      7    7
# 3    56.143356   83.788467   84.262123  111.508369    0.950645      7    7
# 4   111.307358  111.791534  140.027588  140.732849    0.950453      7    7
# 5    83.768845   27.600920  111.499939   56.463421    0.950260      7    7
# 6     0.061498  167.869675   27.601412  196.727982    0.950007      7    7
# 7   139.725494  168.099106  168.005341  196.092621    0.948899      7    7
# 8    55.284168   27.157557   83.766586   56.335835    0.948766      7    7
# 9     0.198977  111.709816   28.216419  140.031036    0.948541      7    7
# 10  112.021744   84.152855  139.780838  111.638710    0.948523      7    7
# ...

# %% [markdown]
# ### Klasifikácia čislice 8 na ARDIS 8x8 vzorke:

# %%
display(Image("yolo_v5/runs/detect/yolo_road_det9/grid8.png"))
results = model("datasets/ardis/ardis_yolo_copy/test/digits_all_8x8/grid8.png")
pd_results = results.pandas().xyxy[0]
print(pd_results.to_string())
# Out:
#           xmin        ymin        xmax        ymax  confidence  class name
# 0   165.722504   84.839508  195.759094  112.058716    0.940022      8    8
# 1     0.000000   28.753897   27.350740   54.586540    0.932862      8    8
# 2   111.681297   28.815306  139.979675   55.527637    0.932182      8    8
# 3   194.430038  139.184448  224.000000  168.204941    0.931396      8    8
# 4    54.953579  140.902954   84.787346  167.924850    0.931295      8    8
# 5   166.211777   56.278378  195.564575   84.552788    0.930845      8    8
# 6     0.000000  141.114517   27.954193  167.239517    0.930545      8    8
# 7   111.753990  196.348785  139.701004  223.489548    0.929833      8    8
# 8     0.000000   85.215775   27.485136  111.252747    0.929707      8    8
# 9   139.120987   83.584747  165.764969  112.104515    0.928956      8    8
# 10   55.643555   29.349159   83.944283   55.470715    0.928311      8    8
# ...

# %% [markdown]
# ### Klasifikácia čislice 9 na ARDIS 8x8 vzorke:

# %%
display(Image("yolo_v5/runs/detect/yolo_road_det9/grid9.png"))
results = model("datasets/ardis/ardis_yolo_copy/test/digits_all_8x8/grid9.png")
pd_results = results.pandas().xyxy[0]
print(pd_results.to_string())
# Out:
#           xmin        ymin        xmax        ymax  confidence  class name
# 0   194.493927   55.240505  223.930939   84.476707    0.946260      9    9
# 1   138.905075   84.123749  167.376266  112.404427    0.944352      9    9
# 2   194.153702   84.412689  223.641800  112.503212    0.943180      9    9
# 3    83.135948   84.025452  112.326553  112.846878    0.942567      9    9
# 4   112.278427   83.672340  139.306808  112.979256    0.941420      9    9
# 5    83.599617  112.274353  112.123672  140.254288    0.941357      9    9
# 6    27.500208   84.095512   56.268215  112.219772    0.940560      9    9
# 7     0.000000  140.328735   27.897961  168.497757    0.940462      9    9
# 8   139.746063  168.607590  167.537521  196.356079    0.940434      9    9
# 9   111.773636   27.725023  139.534653   56.855869    0.939660      9    9
# 10   83.104073  139.998505  112.277443  168.135696    0.938447      9    9
# ...
